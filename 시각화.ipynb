# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], [1,4,9,16])
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0,6,0,20])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0., 5., 0.2)
t
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %%
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
data_dict = {'data_x': [1,2,3,4,5], 'data_y': [2,3,5,10,8]}
plt.plot('data_x', 'data_y', data = data_dict)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], [1,4,9,16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.show()

# %%
import matplotlib.pyplot as plt

font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 14
         }

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=1, fontdict=font2)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [2,3,5,10], label = 'Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc=(1.0, 1.0))

plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [2,3,5,10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0,5])
plt.ylim([0,20])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3], [4,4,4], '-', color = 'C0', label='Solid')
plt.plot([1,2,3], [3,3,3], '--', color = 'C0', label='Dashed')
plt.plot([1,2,3], [2,2,2], ':', color = 'C0', label = 'Dotted')
plt.plot([1,2,3], [1,1,1], '-.', color = 'C0', label = 'Dash-dot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.show()

# %%
plt.plot([1,2,3], [4,4,4], linestyle='solid', linewidth=10,
         color='blue', label='solid')

plt.plot([1,2,3], [2,2,2], linestyle='dashed', linewidth=10,
         color='orange', label='dashed')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.show()

# %%
plt.plot([1,2,3,4], [2,3,5,10], 'bo--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)
x
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8])

# %%
plt.plot(x,x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]
plt.bar(x, values)
plt.xticks(x,years)

plt.show()

# %%
x=np.arange(3)
years=['2018', '2019', '2020']
values=[100, 400, 900]

plt.bar(x, values, color='y')
plt.xticks(x, years)

plt.show()

# %%
x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]
colors = ['y', 'dodgerblue', 'C2']
plt.bar(x, values, color=colors)
plt.xticks(x, years)

plt.show()

# %%
x = np.arange(3)
years=['2018', '2019', '2020']
values=[100, 400, 900]

plt.bar(x, values, width=[0.4, 0.6, 0.8])
plt.xticks(x,years)

plt.show()

# %%
y = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.barh(y, values)
plt.yticks(y, years)

plt.show()

# %%
y = np.arange(3)
years=['2018', '2019', '2020']
values = [100, 400, 900]
colors = ['y', 'dodgerblue', 'C2']

plt.barh(y, values, height=0.4, color=colors)
plt.yticks(y, years)

plt.show()

# %%
np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)

plt.scatter(x,y)
plt.show()

# %%
np.random.seed(0)

n=50
x = np.random.rand(n)
y = np.random.rand(n)

area = (30 * np.random.rand(n))**2
area
# Out:
# array([4.13491732e+02, 6.56138750e+01, 4.86459225e+02, 8.33226117e+02,
#        5.56903138e+01, 2.98761547e+02, 3.15462284e+02, 2.94725019e+02,
#        4.47888733e+01, 8.16957611e+02, 1.79928994e+02, 6.44766877e+02,
#        4.40344131e+02, 7.96218658e+01, 5.96040202e+02, 1.41495122e+02,
#        6.98708560e+02, 3.04090337e+02, 6.99711524e+02, 4.31640003e+02,
#        4.73394393e+02, 2.26193522e+02, 8.22686325e+02, 3.73251039e+02,
#        1.61687792e+02, 3.30941457e+02, 3.31540975e-01, 8.18526330e+01,
#        3.92246190e+02, 7.57305164e+01, 3.43748763e+02, 1.65458339e+02,
#        1.65178999e+01, 8.00751114e+01, 2.92373999e+02, 3.14217558e+02,
#        2.96864542e+02, 3.84004180e+02, 3.82714807e+02, 1.67509680e+02,
#        7.23416219e+02, 1.21591555e+02, 1.70980410e+02, 7.15974544e+02,
#        5.84953873e+02, 4.45913224e+02, 9.04088605e+00, 7.60903449e+02,
#        4.59126571e+02, 8.97925808e+02])

# %%
colors = np.random.rand(n)
colors
# Out:
# array([0.1494483 , 0.86812606, 0.16249293, 0.61555956, 0.12381998,
#        0.84800823, 0.80731896, 0.56910074, 0.4071833 , 0.069167  ,
#        0.69742877, 0.45354268, 0.7220556 , 0.86638233, 0.97552151,
#        0.85580334, 0.01171408, 0.35997806, 0.72999056, 0.17162968,
#        0.52103661, 0.05433799, 0.19999652, 0.01852179, 0.7936977 ,
#        0.22392469, 0.34535168, 0.92808129, 0.7044144 , 0.03183893,
#        0.16469416, 0.6214784 , 0.57722859, 0.23789282, 0.934214  ,
#        0.61396596, 0.5356328 , 0.58990998, 0.73012203, 0.311945  ,
#        0.39822106, 0.20984375, 0.18619301, 0.94437239, 0.7395508 ,
#        0.49045881, 0.22741463, 0.25435648, 0.05802916, 0.43441663])

# %%
plt.scatter(x, y, s=area, c=colors,cmap = "jet")
plt.colorbar()
plt.show()

# %%
weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71,
          80, 59, 67, 81, 69, 73, 69, 74, 70, 65]

plt.hist(weight)
plt.show()

# %%
weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71,
          80, 59, 67, 81, 69, 73, 69, 74, 70, 65]

plt.hist(weight, label = 'bins=10')
plt.hist(weight, bins=30, label='bins=30')
plt.legend()
plt.show()

# %%
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()

# %%
ration = [34,32,16,18]
labels=['Apple', 'Banana', 'Melon', 'Grapes']
explode=[0.05, 0.05, 0.05, 0.05]
colors=['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()

# %%
arr=np.random.standard_normal((30,40))
arr
# Out:
# array([[ 1.12663592, -1.07993151, -1.14746865, ..., -1.1680935 ,
#          0.52327666, -0.17154633],
#        [ 0.77179055,  0.82350415,  2.16323595, ...,  0.41605005,
#         -1.15618243,  0.7811981 ],
#        [ 1.49448454, -2.06998503,  0.42625873, ...,  0.39009332,
#         -0.65240858, -0.39095338],
#        ...,
#        [ 0.96055722,  0.22584048, -0.54949855, ..., -0.82440912,
#          0.42258037,  0.54748057],
#        [-0.81379448, -1.44911761, -1.31771734, ..., -0.34804638,
#         -0.78236697,  0.62511866],
#        [-0.813596  , -0.52164151, -0.07311965, ...,  2.29046707,
#          1.60026782, -0.18883478]])

# %%
plt.matshow(arr)
plt.colorbar()

plt.clim(-1.0, 1.0)
plt.show()

# %%
arr=np.random.standard_normal((30,40))
print(arr)

plt.matshow(arr)
plt.colorbar()

plt.clim(-1.0, 1.0)
plt.show()
# Out:
# [[-0.41227175 -0.40345918 -1.83002855 ...  1.04156839 -0.03926799
#   -0.94893281]
#  [ 0.13191176 -1.98056559  0.76877064 ...  0.50099223 -0.48024903
#    0.93610755]
#  [ 0.8091803  -1.19809288  0.40665709 ... -0.30937759 -0.02852887
#   -0.32473027]
#  ...
#  [-0.39256726 -1.09221794  0.69865023 ... -0.8425717  -1.54292145
#   -0.40176374]
#  [-0.4152314  -0.67366417  0.7979132  ...  0.53698791 -0.41380399
#   -1.09692497]
#  [-0.92736293  0.88833886 -0.52474195 ...  0.79300707  0.63802403
#    0.3400246 ]]

# %%
arr=np.random.standard_normal((30,40))
cmap=plt.get_cmap('bwr')
plt.matshow(arr, cmap=cmap)
plt.colorbar()
plt.show()

# %%
x1=np.linspace(0.0, 5.0)
x2=np.linspace(0.0, 2.0)

y1=np.cos(2*np.pi * x1) * np.exp(-x1)
y2=np.cos(2*np.pi * x2)

plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('1st Graph')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-')
plt.title('2nd Graph')
plt.xlabel('time(s)')
plt.ylabel('Undamped')

plt.tight_layout()
plt.show()

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2*np.pi * x1) * np.exp(-x1)
y2 = np.cos(2*np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.ylabel('Demped oscillation')
plt.xticks(visible=False)

ax2 = plt.subplot(2, 1, 2, sharex = ax1, sharey = ax1)
plt.plot(x2, y2, '.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
plt.show()

# %%
a = 2.0 *np.random.randn(10000) + 1.0

plt.hist(a, bins=100, density=True, histtype='step')
plt.text(6.0, 0.150, 'hello')
plt.show()

# %%
np.random.seed(0)
data_a = np.random.normal(0, 2.0, 1000)
data_b = np.random.normal(-3.0, 1.5, 500)
data_c = np.random.normal(1.2, 1.5, 1500)

fig, ax = plt.subplots()

ax.boxplot([data_a, data_b, data_c])
ax.set_ylim(-10.0, 10.0)
ax.set_xlabel('Data Type')
ax.set_ylabel('Value')

plt.show()
